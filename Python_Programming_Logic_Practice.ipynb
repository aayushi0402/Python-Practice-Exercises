# %% [markdown]
# # Programming Logic

# %% [markdown]
# ## Easy

# %% [markdown]
# #### 1.Write a program to reverse an input and display the reversed input on the screen.

# %% [markdown]
# #### 2.Write a program to find out if a string is a palindrome or not. Ex: Input- Malayalam Output-Palindrome

# %% [markdown]
# #### 3.Write a program that prints the next 20 leap years.

# %% [markdown]
# #### 4.Write a program to count the number of vowels and consonants in a given string.

# %% [markdown]
# #### 5.Write a program to find the factorial of a number.

# %% [markdown]
# #### 6.Write a program to check is an integer number is the power of two.

# %% [markdown]
# ## Moderate

# %% [markdown]
# #### 1.Write a program to reverse a string without using built-in functions

# %% [markdown]
# #### 2.Write a program to print the Fibonacci series

# %% [markdown]
# #### 3.Write a program to print the following triangle
#
# 1
#
# 121
#
# 12321
#
# 1234321

# %% [markdown]
# #### 4. What is the output of the given program?
# ![scores.png](attachment:scores.png)

# %% [markdown]
# #### 5.Given three ints, a b c, return True if one of b or c is "close" (differing from a by at most 1), while the other is "far", differing from both other values by 2 or more. Note: abs(num) computes the absolute value of a number.
#
# close_far(1, 2, 10) → True
#
# close_far(1, 2, 3) → False
#
# close_far(4, 1, 3) → True

# %% [markdown]
# #### 6.Given a day of the week encoded as 0=Sun, 1=Mon, 2=Tue, ...6=Sat, and a boolean indicating if we are on vacation, return a string of the form "7:00" indicating when the alarm clock should ring. Weekdays, the alarm should be "7:00" and on the weekend it should be "10:00". Unless we are on vacation -- then on weekdays it should be "10:00" and weekends it should be "off".
#
# alarm_clock(1, False) → '7:00'
#
# alarm_clock(5, False) → '7:00'
#
# alarm_clock(0, False) → '10:00'
